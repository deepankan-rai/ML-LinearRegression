# %% [markdown]
# <a href="https://colab.research.google.com/github/deepankan-rai/ML-LinearRegression/blob/main/MachineLearningModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Load Dataset**

# %%
import pandas as pd
df= pd.read_csv('https://storage.googleapis.com/kagglesdsdata/datasets/2579793/4397418/delaney_solubility_with_descriptors.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250923%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250923T103702Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...')
df
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data seperation as X and Y**

# %%
y = df['logS']
y
# Out:
# 0      -2.180
# 1      -2.000
# 2      -1.740
# 3      -1.480
# 4      -3.040
#         ...
# 1139    1.144
# 1140   -4.925
# 1141   -3.893
# 1142   -3.790
# 1143   -2.581
# Name: logS, Length: 1144, dtype: float64

# %%
x = df.drop('logS', axis=1) ## axis = 1 means the drop will takes place in column i.e. vertically and axis=0 means it will drop horizontally i.e. rows
x
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 0     2.59540  167.850                0.0            0.000000
# 1     2.37650  133.405                0.0            0.000000
# 2     2.59380  167.850                1.0            0.000000
# 3     2.02890  133.405                1.0            0.000000
# 4     2.91890  187.375                1.0            0.000000
# ...       ...      ...                ...                 ...
# 1139  1.98820  287.343                8.0            0.000000
# 1140  3.42130  286.114                2.0            0.333333
# 1141  3.60960  308.333                4.0            0.695652
# 1142  2.56214  354.815                3.0            0.521739
# 1143  2.02164  179.219                1.0            0.461538
#
# [1144 rows x 4 columns]

# %% [markdown]
# ## **Data Splitting**

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=100)

# %%
x_train
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 253   2.54580  128.215                5.0            0.000000
# 932   1.18500  226.276                4.0            0.000000
# 1070  2.98410  134.222                0.0            0.600000
# 654   2.26290  176.215                3.0            0.461538
# 1005  0.41980  132.126                0.0            1.000000
# ...       ...      ...                ...                 ...
# 802   3.00254  250.301                1.0            0.842105
# 53    2.13860   82.146                3.0            0.000000
# 350   5.76304  256.348                0.0            0.900000
# 79    3.89960  186.339               10.0            0.000000
# 792   2.52334  310.297                3.0            0.300000
#
# [858 rows x 4 columns]

# %%
x_test
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion
# 822   2.91000  172.268                7.0            0.000000
# 118   7.27400  360.882                1.0            0.666667
# 347   1.94040  145.161                0.0            0.909091
# 1123  1.98640  119.378                0.0            0.000000
# 924   1.70062  108.140                0.0            0.750000
# ...       ...      ...                ...                 ...
# 874   0.28300   75.067                1.0            0.000000
# 707   3.14180  372.808                6.0            0.615385
# 301   4.34320  408.498               10.0            0.400000
# 666   2.97670  112.216                1.0            0.000000
# 41    3.45664  156.228                0.0            0.833333
#
# [286 rows x 4 columns]

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear Regression**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Applying the model to make prediction**

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
y_lr_train_pred
# Out:
# array([-2.47913734, -2.09796966, -3.1266494 , -2.80207461, -1.4160102 ,
#        -4.3248288 , -3.54733909, -3.45359974, -9.16425314, -6.53851157,
#        -1.73737272, -4.95017542, -1.5720847 , -1.8924521 , -2.7867637 ,
#        -1.1198855 , -1.61281243, -1.60658314, -5.30720269, -3.88239278,
#         0.72872041, -3.98922255, -2.20228139, -2.64612294, -1.81780767,
#        -4.17837573, -0.3001539 , -3.36771555, -2.95480084, -3.00108973,
#        -1.98946638, -2.96208922, -2.56431736, -6.76322218, -2.3613573 ,
#        -3.13350886, -0.79691028, -1.67080745, -1.18800864, -3.4730818 ,
#        -4.96239693, -4.38972013, -1.56977775, -1.33500682, -2.00697696,
#        -2.64469022, -2.9043066 , -5.16268384, -5.64786735, -3.05938995,
#        -5.18122475, -1.36135566, -4.54952881, -3.72994732, -5.48513416,
#        -3.40764618, -5.99674069, -3.798135  , -5.74344323, -0.21508686,
#        -0.56561417, -1.46881623, -4.20528945, -5.30668148, -5.28576123,
# ...

# %%
y_lr_test_pred
# Out:
# array([-3.03689636e+00, -7.78926890e+00, -2.57905256e+00, -1.99371902e+00,
#        -2.08491700e+00, -1.02674142e+00, -5.74719529e-01, -5.40766289e-01,
#        -5.74344323e+00, -3.93591960e+00, -3.98947673e+00, -2.31851318e+00,
#        -1.47094701e+00, -1.46965560e+00, -4.61730825e+00, -1.91540315e+00,
#        -1.49406613e+00, -3.16108565e+00, -3.71203909e+00, -5.55366717e+00,
#        -3.26992052e+00, -5.06784447e+00, -5.71875510e+00, -2.12431851e+00,
#        -4.33392012e+00, -5.04974024e+00, -3.08312753e+00, -4.39386020e+00,
#        -4.21994719e+00,  5.78166363e-01, -1.43921701e+00, -4.37762220e+00,
#        -2.57499972e+00, -1.51229979e+00, -5.70142683e-01, -1.65154303e+00,
#        -2.77999219e+00, -3.12772295e+00, -5.25806198e+00, -1.76903133e+00,
#        -1.55400771e+00, -2.02426502e+00, -6.58177958e+00, -7.85934368e+00,
#        -5.77941020e+00, -4.16006565e+00, -3.40623859e+00,  1.46635864e+00,
# ...

# %% [markdown]
# ### **Evaluate Model performance**

# %%
from sklearn.metrics import mean_squared_error , r2_score

lr_train_mse = mean_squared_error(y_train,y_lr_train_pred)
lr_train_r2 = r2_score(y_train,y_lr_train_pred)

lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

print("\n Lr train mse:",lr_train_mse)
print("\n Lr train r2:",lr_train_r2)
print("\n Lr test mse:",lr_test_mse)
print("\n Lr test r2:",lr_test_r2)
# Out:
#  Lr train mse: 1.0211498324104205
#
#  Lr train r2: 0.7626677120764102
#
#  Lr test mse: 0.9785998335638344
#
#  Lr test r2: 0.7898615027327966

# %%
lr_results = pd.DataFrame(['Linear Regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Methods' , 'Training MSE', 'Training R2', 'Testing MSE', 'Testing R2']

# %%
lr_results
# Out:
#              Methods Training MSE Training R2 Testing MSE Testing R2
# 0  Linear Regression      1.02115    0.762668      0.9786   0.789862

# %% [markdown]
# ## **Random Forrest**

# %% [markdown]
# ### **Training the model**

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-124015144.py in <cell line: 0>()
#       1 from sklearn.ensemble import RandomForestRegressor
#       2 rf = RandomForestRegressor(max_depth=2, random_state=100)
# ----> 3 rf.fit(x_train,y_train)
#
# NameError: name 'x_train' is not defined
